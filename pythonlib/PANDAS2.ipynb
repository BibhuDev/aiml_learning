# %% [markdown]
# Learning about pandas library.
#
# Used for Data analysis.
# Uploading, analysing and Manipulating dataframes.

# %%
import pandas as pd

# %%
coffee= pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
bios= pd.read_csv('/content/bios.csv')
noc= pd.read_csv('/content/noc_regions.csv')
olympics= pd.read_excel('/content/olympics-data.xlsx')
results= pd.read_csv('/content/results.csv')
results_feather= pd.read_feather('/content/results.feather')
results_parquet= pd.read_parquet('/content/results.parquet')

# %%
print(bios)
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.head(20)
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
# 11          12              Max Decugis  1882-09-24         Paris XVIe
# ...

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[3]
# Out:
# athlete_id                    4
# name            Jacques Brugnon
# born_date            1895-05-11
# born_city           Paris VIIIe
# born_region               Paris
# born_country                FRA
# NOC                      France
# height_cm                 168.0
# weight_kg                  64.0
# died_date            1978-03-20
# Name: 3, dtype: object

# %%
bios.loc[3,'name']
# Out:
# 'Jacques Brugnon'

# %%
bios.loc[3:6, 'name']
# Out:
# 3      Jacques Brugnon
# 4         Albert Canet
# 5    Nicolas Chatelain
# 6        Patrick Chila
# Name: name, dtype: object

# %%
bios.loc[3:6, "height_cm"]
# Out:
# 3    168.0
# 4      NaN
# 5    181.0
# 6    180.0
# Name: height_cm, dtype: float64

# %%
bios.loc[4].height_cm = 169.0
# Out:
# <ipython-input-25-2480455275>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios.loc[4].height_cm = 169.0

# %%
bios.loc[4,'height_cm']
# Out:
# np.float64(nan)

# %%
bios.loc[4].height_cm = 169.0
bios.loc[4,'height_cm']
# Out:
# <ipython-input-26-3064614643>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios.loc[4].height_cm = 169.0
# np.float64(nan)

# %%
print(bios.loc[4,'height_cm'])
# Out:
# nan

# %%
bios.loc[4,'height_cm']=169.0

# %%
bios.loc[4,'height_cm']
# Out:
# np.float64(169.0)

# %% [markdown]
# --thats it for pandas//learn it while building a project--
