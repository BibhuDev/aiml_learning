# %% [markdown]
# Pandas Library:
# Used for data processing and analysis.

# %%
import pandas as pd

# %% [markdown]
# Creating a Pandas Dataframe
#
# since i dont have any datasets with me, i will be using my college attendance report in xls file as a dataset

# %%
attendance_df= pd.read_excel('/attendance.xlsx')
type(attendance_df)
# Out:
# pandas.core.frame.DataFrame

# %%
attendance_df.head()
# Out:
#   ODISHA UNIVERSITY OF TECHNOLOGY AND RESEARCH, BHUBANESWAR Unnamed: 1  \
# 0                          Student Attendance Report               NaN
# 1  Semester:2nd                                  ...               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#                  Unnamed: 2    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                       NaN           NaN        NaN        NaN        NaN
# 1                       NaN           NaN        NaN        NaN        NaN
# 2           Class Started :           NaN        NaN        NaN        NaN
# 3  Attendance report till :           NaN        NaN        NaN        NaN
# 4                       NaN  % Attendance        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# ...

# %%
print(attendance_df)
# Out:
#    ODISHA UNIVERSITY OF TECHNOLOGY AND RESEARCH, BHUBANESWAR Unnamed: 1  \
# 0                           Student Attendance Report               NaN
# 1   Semester:2nd                                  ...               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                        Subject Name               NaN
# 6                                        Subject Code               NaN
# 7                                                 NaN               NaN
# 8                                                 Sno           Roll No
# 9                                                   1          24140003
# 10                                                  2          24140004
# 11                                                  3          24140005
# ...

# %%
attendance_df.shape
# Out:
# (29, 11)

# %%
##due to unavailability of proper datasets i am skipping this pandas topic and will learn it during building projects
